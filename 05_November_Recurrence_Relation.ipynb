# %% [markdown]
# 1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %% [markdown]
# T(2)
#
# = 3T(1) + 12 * 2
#
# = 3(3T(0) + 12 * 1) + 12 * 2
#
# = 3^2 T(0) + 3 * 12 * 1 + 12 * 2
#
# = 3^2 * 5 + 36 + 24
#
# = 9 * 5 + 60
#
# = 45 + 60
#
# = 105
# ​
# T(2)=105.

# %% [markdown]
# 2. Given a recurrence relation, solve it using the substitution method:
#
# a. T(n) = T(n-1) + c
#
# b. T(n) = 2T(n/2) + n
#
# c. T(n) = 2T(n/2) + c
#
# d. T(n) = T(n/2) + c

# %% [markdown]
# a. Let's count the number of recursive calls:
#
#         { 1           n=0
#
# T(n)=   {
#
#         { T(n-1)+c    n>0
#
# T(n) = T(n-1) + c
#
# T(n-1) = T(n-1-1) + c, where n is changed to n-1
#
# so, T(n-1) = T(n-2) + c
#
#
# T(n) = T(n−1) + c
#
# T(n) = T(n−2) + c + c
#
# T(n) = T(n−3) + c + c + c
#
#         .
#
#         .   K times
#
#         .
#
# T(n) = T(n-k) + k * c
#
#
# Where assuming n-k=0, then value of k=n
#
# T(n) = T(n-n) + n * c
#
# T(n) = T(0) + n * c
#
# T(n) = 1 + n * c
#
# T(n) = O(n) , ignoring constants because O(n) > O(1)
#
# The number of recursive calls is n, and at each call, a constant amount of work (c) is done.
#
# Therefore, the time complexity T(n) is O(n), indicating a linear time complexity.

# %% [markdown]
# b. T(n) = 2T(n/2) + n
#
#        { 1            n=1
#
# T(n) = {
#
#        { 2T(n/2) + n, n>1
#
#
# T(n) = 2T(n/2) + n              , equation 1
#
# T(n/2) = 2T(n/2/2) + n/2
#
# T(n/2) = 2T(n/2^2) + n/2
#
# T(n/2^2) = 2T(n/2^3) + n/2^2
#
# ***************************
#
#
# T(n) = 2[2T(n/2^2) + n/2] + n
#
# T(n) = 2^2 * T(n/2^2) + 2n/2 + n
#
# T(n) = 2^2 * T(n/2^2) + n + n , equation 2
#
#               .
#
#               .   K times
#
#               .
#
# T(n) = 2^k * T(n/2^k) + k * n
#
# ********************************
#
# Assumptions:
#
# T(n/2^k) = T(1)
#
# n/2^k = 1
#
# n=2^k
#
# k=log n
#
# ********************************
#
#
# T(n) = 2^k * T(n/2^k) + k * n
#
# T(n) = n * T(n/n) + log n * n
#
# T(n) = n * 1 + n log n , pick the highest term
#
# T(n) = O(n log n)

# %% [markdown]
# c. T(n) = 2T(n/2) + c
#
#        { 1            n=1
#
# T(n) = {
#
#        { 2T(n/2) + c, n>1
#
# T(n) = 2T(n/2) + c , equation 1
#
#
# *********************************
#
# Assumptions
#
# T(n) = 2T(n/2) + c
#
# T(n/2) = 2T(n/2/2) + c
#
# T(n/2) = 2T(n/2^2) + c
#
# **********************************
#
# T(n) = 2[2T(n/2^2) + c] + c
#
# T(n) = 2^2 * T(n/2^2) + 2 * c , equation 2
#
# T(n) = 2^3 * T(n/2^3) + 3 * c , equation 3
#
#             .
#
#             .   K times
#
#             .
#
# T(n) = 2^k * T(n/2^k) + k * c , equation 4
#
# *********************************************
#
# Assumptions
#
# n/2^k = 1
#
# n = 2^k
#
# k = log n
#
# ********************************************
#
# T(n) = 2^k * T(n/2^k) + k * c
#
# T(n) = n * T(1) + log n * c ,    where T(1) = 1    n=1
#
# T(n) = n * 1 + log n * c
#
# T(n) = n + log n * c , ignoring the constant 'c' and lower values like 'log n' but considering only bigger values.
#
# T(n) = O(n)

# %% [markdown]
# d. T(n) = T(n/2) + c
#
#        { 1            n=1
#
# T(n) = {
#
#        { T(n/2) + c,  n>1
#
# T(n) = T(n/2) + c , equation 1
#
# **********
#
# Assumptions
#
# T(n) = T(n/2) + c
#
# T(n/2) = T(n/2/2) + c
#
# T(n/2) = T(n/2^2) + c
#
# T(n/2^2) = T(n/2^2/2^2) + c
#
# T(n/2^2) = T(n/2^4) + c
#
# ************
#
# T(n) = [T(n/2^2) + c] + c , equation 2
#
# T(n) = T(n/2^2) + 2c
#
# T(n) = [T(n/2^4) + c] + 2c
#
# T(n) = T(n/2^4) + 3c , equation 3
#
#            .
#
#            .  k times
#
#            .
#
# T(n) = T(n/2^k) + k * c , equation 4
#
# *******************
#
# Assumptions
#
# n/2^k=1
#
# n=2^k
#
# k=log n
#
# ********************
#
#
# T(n) = T(n/2^k) + k * c
#
# T(n) = T(1) + log n * c
#
# T(n) = 1 + log n * c, where T(1) is { 1   n=1 } and ignoring constants and considering bigger values in worst case
#
# T(n) = O(log n)

# %% [markdown]
# 3. Given a recurrence relation, solve it using the recursive tree approach:
#
# a. T(n) = 2T(n-1) +1
#
# b. T(n) = 2T(n/2) + n

# %% [markdown]
# a. T(n) = 2T(n-1) +1
#
#         {   1               n=0
#
# T(n) =  {
#
#         {   2T(n-1) + 1     n>0
#
# Here, T(n) is having 2 time of n-1 which is 2T(n-1)
#
# ***************************
#
#                 T(n)                                   2^0, Here T(n) of node is taking 1 unit of time=1
#             /   |               \
#           1   T(n-1)            T(n-1)              2^1,T(n-1) of left and right node is taking 1 + 1 unit of time=2
#             /   |      \        /   |      \
#            1   T(n-2)  T(n-2)   1   T(n-2)  T(n-2)    2^2,T(n-2) of left and right node is taking 2 + 2 units of time=4
#                         .
#                         .   k times
#                         .
#         T(n-k)            T(n-k)                    2^k,Here T(n-k) of left and right node is taking k units of time=k
#
# ***************************
#
# 2^0 + 2^1 + 2^2 + 2^3 + ... + 2^k
#
# This is Geometric progression series
#
# ar^0 + ar^1 + ar^2 + ar^3 + ... + ar^k
#
# = a(r^k+1 - 1)/r-1
#
# Where a=1 and r=2
#
# = 1(2^k+1 - 1)/2 - 1
#
# = 2^k+1 - 1/1
#
# = 2^k+1 -1
#
# ****************
#
# Assumptions
#
# n-k=0
#
# n=k
#
# ****************
#
# = 2^n+1 - 1
#
# = 2^n   , ignoring the constants
#
# = O(2^n)

# %% [markdown]
# b. T(n) = 2T(n/2) + n
#
#         {   1               n=1
#
# T(n) =  {
#
#         {   2T(n/2) + n      n>1
#
# Here, T(n) is having 2 time of n/2 which is 2T(n/2)
#
# ***************************
#                  T(n)                                    n, T(n) of node is taking n unit of time=n
#                 /                    \
#              T(n/2)                  T(n/2)              n, T(n/2) of left and right node is taking n unit of time=n
#              /      \                /       \
#         T(n/2^2)  T(n/2^2)          T(n/2^2)  T(n/2^2)   n, T(n/2^2) of left and right node is taking n unit of time=n
#                                 .
#                                 .   k times
#                                 .
#                 T(n/2^k)                   T(n/2^k)    n*k, T(n/2^k) of left and right node is taking n unit of time=n
#
# **************************
#
# = n + n + ... + n * k
#
#
# ********************
#
# Assumptions
#
# n/2^k = 1
#
# n= 2^k
#
# k= log n
#
# *********************
#
# = n * k
#
# = n * log n
#
# = O(n log n)
#
# T(n) = O(n log n)
